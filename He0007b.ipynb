# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from statistics import *
from matplotlib.lines import Line2D 
from matplotlib.figure import *

# %% [markdown]
# ## Elements in Ret II

# %%
#Legend
legend_elements = [Line2D([0], [0], marker='s', color='w', label='He0007',
                          markerfacecolor='red', markersize=12),
                  Line2D([0], [0], marker='P', color='w', label='Ret II',
                          markerfacecolor='b', markersize=15),
                  Line2D([0], [0], marker='o', color='w', label='MW Halo Stars',
                          markerfacecolor='grey', markersize=12, alpha=0.25)]

# Create the figure
fig, ax = plt.subplots()
ax.legend(handles=legend_elements, loc='center',mode = "expand", ncol = 4)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white') 
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %%
#C in Ret II
data = np.genfromtxt("c.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.77,-2.08,-3.01,-3.42,-2.73,-2.19,-2.93]
rety=[0.2,0.85,0.35,0.65,0.13,0.15,0.5,0.26]
plt.scatter(retx,rety, color='b',marker='P')

He=-2.4
plt.scatter(He,-0.35, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("C/Fe")
plt.xlim(-5, -1)
plt.ylim(-1,1.5)
plt.title("Relative Abundance of C in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of C in He0007 and Ret II')

# %%
#Na in Ret II
data = np.genfromtxt("na.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.77,-2.08,-3.01,-2.73,-2.19,-3.54]
rety=[0.35,-0.1,0.09,0.3,0.14,-0.09,0.48]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-0.56, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Na/Fe")
plt.xlim(-4.5, -1)
plt.ylim(-1,1.5)
plt.title("Relative Abundance of Na in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Na in He0007 and Ret II')

# %%
#Mg in UFDs
data = np.genfromtxt("mg.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.77,-2.08,-3.01,-3.42,-2.73,-2.19,-3.54,-2.93]
rety=[0.45,0.17,0.24,0.46,0.81,0.18,-0.08,0.54,0.34]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-0.34, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Mg/Fe")
plt.xlim(-4.5, -1)
plt.ylim(-0.75,1.5)
plt.title("Relative Abundance of Mg in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Mg in He0007 and Ret II')

# %%
#Al in UFDs
data = np.genfromtxt("al.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.08,-3.01]
rety=[-0.75,-0.99,-0.66]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-1.64, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Al/Fe")
plt.xlim(-4.5, -1)
plt.ylim(-2,1)
plt.title("Relative Abundance of Al in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Al in He0007 and Ret II')

# %%
#Si in UFDs
data = np.genfromtxt("si.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.08,-3.01,-2.73,-2.19]
rety=[0.26,0.55,0.69,0.3,0.02]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-0.34, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Si/Fe")
plt.title("Relative Abundance of Si in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Si in He0007 and Ret II')

# %%
#Ca in UFDs
data = np.genfromtxt("ca.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.77,-2.08,-3.01,-2.73,-2.19,-3.54]
rety=[0.32,0.42,0.32,0.2,0.19,0.39,0.43]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,0.25, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Ca/Fe")
plt.xlim(-4.5, -1.5)
plt.ylim(-0.4,1)
plt.title("Relative Abundance of Ca in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Ca in He0007 and Ret II')

# %%
#Sc in UFDs
data = np.genfromtxt("sc.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.77,-2.08,-3.01,-3.42,-2.73,-2.19,-3.54,-2.93]
rety=[-0.08,0.16,0.3,-0.17,1.06,0,-0.68,0.1,0.48]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-0.97, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Sc/Fe")
plt.xlim(-4.5, -1.5)
plt.ylim(-1.25,1.25)
plt.title("Relative Abundance of Sc in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Sc in He0007 and Ret II')

# %%
#Ti in UFDs
data = np.genfromtxt("ti.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.77,-2.08,-3.01,-2.19,-3.54]
rety=[0.45,0.48,0.16,0.4,0.62]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-0.23, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Ti/Fe")
plt.xlim(-4.5, -1)
plt.ylim(-0.4,1)
plt.title("Relative Abundance of Ti in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Ti in He0007 and Ret II')

# %%
#V in UFDs
data = np.genfromtxt("v.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.93]
rety=[0.24]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,0.07, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("V/Fe")
plt.xlim(-3.5, -1.5)
plt.ylim(-0.5,1)
plt.title("Relative Abundance of V in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of V in He0007 and Ret II')

# %%
#Cr in UFDs
data = np.genfromtxt("cr.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.77,-2.08,-3.01,-3.42,-2.73,-2.19,-3.54]
rety=[-0.19,-0.5,-0.19,-0.41,0.01,-0.4,0.02,-0.52]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,0.11, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Cr/Fe")
plt.xlim(-5, -1)
plt.ylim(-1,0.5)
plt.title("Relative Abundance of Cr in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Cr in He0007 and Ret II')

# %%
#Mn in UFDs
data = np.genfromtxt("mn.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-2.08,-3.01,-2.19,-2.93]
rety=[-1.0,-0.7,-0.38,-0.4,-0.12]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-0.66, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Mn/Fe")
plt.xlim(-5, -1)
plt.ylim(-1.3,0.4)
plt.title("Relative Abundance of Mn in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Mn in He0007 and Ret II')

# %%
#Co in UFDs
data = np.genfromtxt("co.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-3.01,-2.19]
rety=[0.37,0.06,0.21]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-0.33, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Co/Fe")
plt.xlim(-4.5, -1)
plt.ylim(-0.5,1)
plt.title("Relative Abundance of Co in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Co in He0007 and Ret II')

# %%
#Ni in UFDs
data = np.genfromtxt("ni.giant.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='grey', alpha=0.075)

retx=[-2.91,-3.01,-3.42,-2.19,-2.93]
rety=[0,-0.17,1.15,0.07,0.21]
plt.scatter(retx,rety, color='b',marker='P')

plt.scatter(He,-0.5, color='red', marker='s')
plt.xlabel("Fe/H")
plt.ylabel("Ni/Fe")
plt.xlim(-4.5, -1)
plt.ylim(-0.75,1.25)
plt.title("Relative Abundance of Ni in He0007 and Ret II")
# Out:
# Text(0.5, 1.0, 'Relative Abundance of Ni in He0007 and Ret II')

# %% [markdown]
# ## Misc Data

# %%
euhe0007= -0.598
eusolar= 0.495
euj033523= -0.81
scalehe= euhe0007 - eusolar
#DES J033523−540407
scalej1= euj033523 - eusolar
#DES J033607−540235
euj033607= -0.71
scalej2= euj033607- eusolar
#DES J033447−540525
euJ033447= -0.52
scalej3= euJ033447- eusolar
#DES J033531−540148; upper limit
euJ033531= -1.32
scalej4= euJ033531 - eusolar
#DES J033548−540349
euJ033548= -0.72
scalej5= euJ033548 - eusolar
#DES J033537−540401
euJ033537= -0.51
scalej6= euJ033537 - eusolar
#DES J033556−540316; upper limit
euJ033556=-0.62
scalej7= euJ033556 - eusolar
#DES J033457−540531
euJ033457=0.21
scalej8= euJ033457 - eusolar
#DES J033454−540558
euJ033454= -0.14
scalej9= euJ033454 - eusolar
print(scalej9)
# Out:
# -0.635

# %%
heAN=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,40,56,57,58,59,60,62,63,64,66]
heEW=[5.71,3.3,4.89,2.43,4.21,-0.2,2.34,3.04,2.4,5.12,2.28,3.34,0.76,-0.141,0.556,0.8,-0.427,-0.074,-0.786,0.029,-0.388,-0.598,0.137,0.179]
j0AN1=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,40,56,57,58,59,60,62,63,64,66]
j0EW1=[6.07,3.53,5.05,2.78,3.53,-0.03,2.23,2.22,2.04,4.49,2.04,3.04,0.03,-0.48,0.08,-0.04,-0.81,-0.51,-1.09,-0.21,-0.65,-0.81,-0.47,-0.29]

# %%
j0AN2=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,40,56,57,58,59,60,62,63,64,66]
j0EW2=[5.86,3.42,5.01,2.74,3.74,0.32,2.34,2.44,1.59,4.53,2.34,3.10,0.53,-0.12,0.46,0.12,-0.64,-0.15,-0.67,-0.01,-0.28,-0.71,-0.14,-0.15]
j0AN3=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,40,56,57,58,59,60,62,63,66]
j0EW3=[5.72,3.68,5.14,2.79,3.75,0.16,2.21,2.54,1.52,4.59,2.45,3.31,0.32,-0.21,0.59,0.35,-0.51,-0.02,-0.79,0.25,-0.06,-0.52,0.2]

j0AN4=[6,11,12,13,20,21,22,24,25,26,27,28,38,56,63]
j0EW4=[5.29,3.81,4.95,2.44,3.32,0.11,2.04,2.07,1.34,4.16,2.39,2.71,-1.3,-1.69,-1.32]
j0AN5=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,56,60,63,66]
j0EW5=[6.74,3.96,5.33,3.66,4.54,0.28,3.39,3.47,2.84,5.31,3.01,4.10,0.33,-0.09,0.35,0.35,-0.72,0.15]
j0AN6=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,56,63,66]
j0EW6=[5.85,3.65,5.05,3.6,3.8,0.42,2.51,2.51,3.7,4.77,3.51,4.86,0.36,0.41,0.85,-0.51,0.16]

j0AN7=[6,11,12,13,20,21,22,24,25,26,27,28,38,56,63]
j0EW7=[6.09,3.18,4.6,2.71,3.23,-0.29,2.03,1.58,2.69,3.96,2.6,4.76,-0.67,-1.26,-0.62]
j0AN8=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,56,58,60,63,66]
j0EW8=[6.7,4.25,5.76,3.38,4.58,1.37,3.35,3.37,2.65,5.42,4.24,4.46,1.17,0.98,1.46,0.75,1.18,0.21,1.22]
j0AN9=[6,11,12,13,20,21,22,24,25,26,27,28,38,56,63]
j0EW9=[6.51,3.37,5.0,3.76,3.99,0.54,2.63,2.37,4.17,4.73,3.84,5.01,0.4,0.81,-0.14]

# %%
plt.scatter(j0AN9, j0EW9)

# %%
scheEW= [x - scalehe for x in heEW]
scj0EW1= [x - scalej1 for x in j0EW1]
scj0EW2= [x - scalej2 for x in j0EW2]
scj0EW3= [x - scalej3 for x in j0EW3]
scj0EW4= [x - scalej4 for x in j0EW4]
scj0EW5= [x - scalej5 for x in j0EW5]
scj0EW6= [x - scalej6 for x in j0EW6]
scj0EW7= [x - scalej7 for x in j0EW7]
scj0EW8= [x - scalej8 for x in j0EW8]
scj0EW9= [x - scalej9 for x in j0EW9]

# %%
import matplotlib.gridspec as gridspec
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
difference1 = list(np.array(scheEW) - np.array(scj0EW1))
difference2 = list(np.array(scheEW) - np.array(scj0EW2))
heAN3=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,40,56,57,58,59,60,62,63,66]
heEW3=[5.71,3.3,4.89,2.43,4.21,-0.2,2.34,3.04,2.4,5.12,2.28,3.34,0.76,-0.141,0.556,0.8,-0.427,-0.074,-0.786,0.029,-0.388,-0.598,0.179]
scheEW3= [x - scalehe for x in heEW3]
difference3 = list(np.array(scheEW3) - np.array(scj0EW3))
heAN5=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,56,60,63,66]
heEW5=[5.71,3.3,4.89,2.43,4.21,-0.2,2.34,3.04,2.4,5.12,2.28,3.34,0.76,-0.141,0.18,0.029,-0.598,0.179]
scheEW5= [x - scalehe for x in heEW5]
difference5 = list(np.array(scheEW5) - np.array(scj0EW5))
heAN6=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,56,63,66]
heEW6=[5.71,3.3,4.89,2.43,4.21,-0.2,2.34,3.04,2.4,5.12,2.28,3.34,0.76,-0.141,0.18,-0.598,0.179]
scheEW6= [x - scalehe for x in heEW6]
difference6 = list(np.array(scheEW6) - np.array(scj0EW6))
heAN8=[6,11,12,13,20,21,22,24,25,26,27,28,38,39,56,58,60,63,66]
heEW8=[5.71,3.3,4.89,2.43,4.21,-0.20,2.34,3.04,2.4,5.12,2.28,3.34,0.76,-0.141,0.18,-0.074,0.029,-0.598,0.179]
scheEW8= [x - scalehe for x in heEW8]
difference8 = list(np.array(scheEW8) - np.array(scj0EW8))
heAN9=[6,11,12,13,20,21,22,24,25,26,27,28,38,56,63]
heEW9=[5.71,3.3,4.89,2.43,4.21,-0.20,2.34,3.04,2.4,5.12,2.28,3.34,0.076,0.18,-0.598]
scheEW9= [x - scalehe for x in heEW9]
difference9 = list(np.array(scheEW9) - np.array(scj0EW9))

# %%
print(difference5)
# Out:
# [-1.1520000000000001, -0.782, -0.5620000000000003, -1.3519999999999999, -0.45199999999999996, -0.6019999999999999, -1.1720000000000006, -0.5520000000000005, -0.5619999999999998, -0.3119999999999994, -0.8519999999999999, -0.8819999999999997, 0.30800000000000005, -0.17299999999999982, -0.29200000000000004, -0.44300000000000006, 1.1102230246251565e-16, -0.09299999999999975]

# %%
fig, axs = plt.subplots(2, sharex=True, sharey=False, gridspec_kw={'hspace': 0, 'height_ratios': [3, 1]})
fig.suptitle('Abundance Pattern Differences between He0007 and Reticulum II')
axs[0].scatter(j0AN1,scj0EW1,color='blue', alpha=0.25, label='J033523')
axs[0].scatter(j0AN2,scj0EW2,color='orange', alpha=0.25)
axs[0].scatter(j0AN3,scj0EW3,color='yellow', alpha=0.25)
axs[0].scatter(j0AN5,scj0EW5,color='green', alpha=0.25)
axs[0].scatter(j0AN6,scj0EW6,color='purple', alpha=0.25)
axs[0].scatter(j0AN8,scj0EW8,color='brown', alpha=0.25)
axs[0].scatter(j0AN9,scj0EW9,color='red', alpha=0.25)
axs[0].scatter(heAN,scheEW,color='black', marker='s')
axs[1].axhline(y=0, color='grey', alpha=0.25)
axs[1].scatter(j0AN1,difference1,color='blue', marker='*', alpha=0.5)
axs[1].scatter(j0AN2,difference2,color='orange', marker='*', alpha=0.5)
axs[1].scatter(j0AN3,difference3,color='yellow', marker='*', alpha=0.5)
axs[1].scatter(j0AN5,difference5,color='green', marker='*', alpha=0.5)
axs[1].scatter(j0AN6,difference6,color='purple', marker='*', alpha=0.5)
axs[1].scatter(j0AN8,difference8,color='brown', marker='*', alpha=0.5)
axs[1].scatter(j0AN9,difference9,color='red', marker='*', alpha=0.5)

axs[1].set(ylim=(-2,1.5))
axs[1].xaxis.set_minor_locator(MultipleLocator(1))

axs[0].set(ylabel='logε(x)')
axs[1].set(ylabel='Δ logε(x)')
axs[1].set(xlabel='Z (Atomic Number)')

legend_elements = [Line2D([0], [0], marker='.', color='w', label='J033523',
                          markerfacecolor='b', markersize=15, alpha=0.5),
                  Line2D([0], [0], marker='.', color='w', label='J033607',
                          markerfacecolor='orange', markersize=15, alpha=0.5),
                Line2D([0], [0], marker='.', color='w', label='J033447',
                          markerfacecolor='yellow', markersize=15, alpha=0.5),
                   Line2D([0], [0], marker='.', color='w', label='J033548',
                          markerfacecolor='green', markersize=15, alpha=0.5),
                    Line2D([0], [0], marker='.', color='w', label='J033537',
                          markerfacecolor='purple', markersize=15, alpha=0.5),
                   Line2D([0], [0], marker='.', color='w', label='J033457',
                          markerfacecolor='brown', markersize=15, alpha=0.5),
                   Line2D([0], [0], marker='.', color='w', label='J033454',
                          markerfacecolor='red', markersize=15, alpha=0.5),
                  Line2D([0], [0], marker='s', color='w', label='J0010-1753',
                          markerfacecolor='black', markersize=10)]
plt.legend(handles=legend_elements, bbox_to_anchor=(1.05, 4.0), loc='upper left')


# Hide x labels and tick labels for all but bottom plot.
for ax in axs:
    ax.label_outer()

# %%
#[Y/Eu]
data = np.genfromtxt("y.eu.halo.csv", delimiter=",", names=["x", "y"])
plt.scatter(data['x'], data['y'], color='grey', alpha=0.2, label='Milky Way Halo')
data = np.genfromtxt("y.eu.ufd.csv", delimiter=",", names=["a", "b"])
plt.scatter(data['a'], data['b'], color='blue', label='Ultra Faint Dwarf Galaxies')
data = np.genfromtxt("y.eu.dwarf.csv", delimiter=",", names=["m", "n"])
plt.scatter(data['m'], data['n'], color='red', label='Classical Dwarf Galaxies')
plt.scatter(-2.4,-1.23, color='black', marker='s', label='He0007')
plt.xlabel("Fe/H")
plt.ylabel("Y/Eu")
plt.xlim(-3.5, -0.25)
plt.ylim(-1.5,0.75)
plt.title("Yttrium Abundance with respect to Europium")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
data = np.genfromtxt("y.eu.csv", delimiter=",", names=["r", "s"])

# %% [markdown]
# ## Masses

# %%
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Hercules',
                          markerfacecolor='m', markersize=13),
                   Line2D([0], [0], marker='o', color='w', label='U Ma II',
                          markerfacecolor='orange', markersize=13),
                   Line2D([0], [0], marker='o', color='w', label='ComBer',
                          markerfacecolor='yellow', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Leo IV',
                          markerfacecolor='cyan', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='CVn I',
                          markerfacecolor='brown', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='CVn II',
                          markerfacecolor='purple', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Ret II',
                          markerfacecolor='b', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Bootes I',
                          markerfacecolor='lime', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Bootes II',
                          markerfacecolor='red', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Horoglium I',
                          markerfacecolor='grey', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Tuc II',
                          markerfacecolor='g', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Tuc III',
                          markerfacecolor='pink', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Segue I',
                          markerfacecolor='teal', markersize=13),
                  Line2D([0], [0], marker='o', color='w', label='Segue II',
                          markerfacecolor='black', markersize=13)]

# Create the figure
fig, ax = plt.subplots()
ax.legend(handles=legend_elements, loc='center',mode = "expand", ncol = 4)
ax.spines['bottom'].set_color('white')
ax.spines['top'].set_color('white') 
ax.spines['right'].set_color('white')
ax.spines['left'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %%
#Mg in UFDs with Masses
herx=[-2.07,-2.09,-2.52,-2.83]
hery=[0.79,0.75,0.19,0.3]
s0=500
plt.scatter(herx,hery,s=s0, color='m')

booiix=[-2.86,-2.87,-2.63,-2.92]
booiiy=[0.42,0.26,0.39,0.42]
s1=300
plt.scatter(booiix,booiiy,s=s1, color='red')

umax=[-3.15,-3.28,-2.39]
umay=[0.42,0.45,0.74]
s2=350
plt.scatter(umax,umay,s=s2, color='orange')

comx=[-2.36,-2.93,-2.58]
comy=[0.14,0.96,0.48]
s3=1
plt.scatter(comx,comy,s=s3, color='yellow')

booix=[-2.93,-2.58,-3.71,-3.06,-2.33,-2.64,-2.16,-3.44,-2.15,-2.28,-1.99,-1.8,-3.18,-2.49]
booiy=[0.96,0.48,0.45,0.29,0.41,0.13,0.35,1.14,0.05,0.34,0.41,0.47,0.39,0.2]
s4=700
plt.scatter(booix,booiy,s=s4, color='lime')

retx=[-2.91,-2.77,-2.08,-3.01,-3.42,-2.73,-2.19,-3.54,-2.93]
rety=[0.45,0.17,0.24,0.46,0.81,0.18,-0.08,0.54,0.34]
s5=350
plt.scatter(retx,rety,s=s5, color='b')

leox=[-3.19,-2.88,-2.18]
leoy=[0.32,0.4,-0.1]
s6=250
plt.scatter(leox,leoy,s=s6, color='cyan')

cvniix=[-2.58]
cvniiy=[0.12]
s7=1
plt.scatter(cvniix,cvniiy,s=s7, color='purple')

cvnix=[-2.18,-2.52]
cvniy=[-0.04,0.46]
s8=1000
plt.scatter(cvnix,cvniy,s=s8, color='brown')

horx=[-2.43,-2.6,-2.83]
hory=[-0.02,-0.23,-0.03]
s9=200
plt.scatter(horx,hory, s=s9, color='grey')

tuciiix=[-2.61,-2.69,-2.69,-2.58]
tuciiiy=[0.45,0.5,0.4,0.64]
s10=1
plt.scatter(tuciiix,tuciiiy, s=s10, color='pink')

tuciix=[-2.93,-2.92,-2.41,-3.23,-2.69,-3.08,-3.34]
tuciiy=[-0.04,0.51,0.16,0.36,0.42,0.38,0.45]
s11=1
plt.scatter(tuciix,tuciiy, s=s11, color='g')

segix=[-1.42,-1.67,-2.32,-2.4,-3.6,-3.78,-3.57]
segiy=[0.38,0.47,0.52,0.54,0.59,0.57,0.92]
s12=100
plt.scatter(segix,segiy, s=s12, color='teal')

segiix=[-2.9]
segiiy=[0.31]
s13=400
plt.scatter(segiix,segiiy, s=s13, color='black')

plt.scatter(-2.4,-0.34, color='red', marker='*')
plt.xlabel("Fe/H")
plt.ylabel("Mg/Fe")
plt.xlim(-4.25, -1.25)
plt.ylim(-0.4,1.5)
plt.title("Mg/Fe vs Fe/H with Masses Included")
# Out:
# Text(0.5, 1.0, 'Mg/Fe vs Fe/H with Masses Included')

# %%
herx=[-2.07,-2.09,-2.52,-2.83]
hery=[0.79,0.75,0.19,0.3]
s0=500
plt.scatter(herx,hery,color='m', marker='^', s=100)

booiix=[-2.86,-2.87,-2.63,-2.92]
booiiy=[0.42,0.26,0.39,0.42]
s1=300
plt.scatter(booiix,booiiy, color='red', marker='^',s=100)

umax=[-3.15,-3.28,-2.39]
umay=[0.42,0.45,0.74]
s2=350
plt.scatter(umax,umay, color='orange', marker='^',s=100)

comx=[-2.36,-2.93,-2.58]
comy=[0.14,0.96,0.48]
s3=1
plt.scatter(comx,comy,s=s3, color='yellow')

booix=[-2.93,-2.58,-3.71,-3.06,-2.33,-2.64,-2.16,-3.44,-2.15,-2.28,-1.99,-1.8,-3.18,-2.49]
booiy=[0.96,0.48,0.45,0.29,0.41,0.13,0.35,1.14,0.05,0.34,0.41,0.47,0.39,0.2]
s4=700
plt.scatter(booix,booiy,color='lime', marker='s',s=100)

retx=[-2.91,-2.77,-2.08,-3.01,-3.42,-2.73,-2.19,-3.54,-2.93]
rety=[0.45,0.17,0.24,0.46,0.81,0.18,-0.08,0.54,0.34]
s5=350
plt.scatter(retx,rety, color='b', marker='^',s=100)

leox=[-3.19,-2.88,-2.18]
leoy=[0.32,0.4,-0.1]
s6=250
plt.scatter(leox,leoy,color='cyan',marker='^',s=100)

cvniix=[-2.58]
cvniiy=[0.12]
s7=1
plt.scatter(cvniix,cvniiy,s=s7, color='purple')

cvnix=[-2.18,-2.52]
cvniy=[-0.04,0.46]
s8=1000
plt.scatter(cvnix,cvniy, color='brown', marker='s',s=100)

horx=[-2.43,-2.6,-2.83]
hory=[-0.02,-0.23,-0.03]
s9=200
plt.scatter(horx,hory,color='grey', s=100)

tuciiix=[-2.61,-2.69,-2.69,-2.58]
tuciiiy=[0.45,0.5,0.4,0.64]
s10=1
plt.scatter(tuciiix,tuciiiy, s=s10, color='pink')

tuciix=[-2.93,-2.92,-2.41,-3.23,-2.69,-3.08,-3.34]
tuciiy=[-0.04,0.51,0.16,0.36,0.42,0.38,0.45]
s11=1
plt.scatter(tuciix,tuciiy, s=s11, color='g')

segix=[-1.42,-1.67,-2.32,-2.4,-3.6,-3.78,-3.57]
segiy=[0.38,0.47,0.52,0.54,0.59,0.57,0.92]
s12=100
plt.scatter(segix,segiy, color='teal', s=100)

segiix=[-2.9]
segiiy=[0.31]
s13=400
plt.scatter(segiix,segiiy, color='black', marker='^',s=100)

plt.scatter(-2.4,-0.34, color='red', marker='*',s=100)
plt.xlabel("Fe/H")
plt.ylabel("Mg/Fe")
plt.xlim(-4, -1.25)
plt.ylim(-0.4,1.2)
plt.title("Mg/Fe vs Fe/H with Masses Included")

legend_elements = [Line2D([0], [0], marker='o', color='w', label='Order of 10^5 Solar Masses',
                          markerfacecolor='black', markersize=12,),
                  Line2D([0], [0], marker='^', color='w', label='Order of 10^6 Solar Masses',
                          markerfacecolor='black', markersize=12),
                Line2D([0], [0], marker='s', color='w', label='Order of 10^7 Solar Masses',
                          markerfacecolor='black', markersize=12)]
plt.legend(handles=legend_elements, bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
#Mg vs Mass
herx=[0.5075]
hery=[70]
plt.scatter(hery,herx,color='m')

booiix=[0.3725]
booiiy=[26.3]
plt.scatter(booiiy,booiix, color='red')

umax=[0.5366]
umay=[50]
plt.scatter(umay,umax, color='orange')

comx=[0.5266]

booix=[0.4335]
booiy=[100]
plt.scatter(booiy,booix,color='lime')

retx=[0.3455]
rety=[47]
plt.scatter(rety,retx, color='b')

leox=[0.2066]
leoy=[15]
plt.scatter(leoy,leox,color='cyan')

cnviix=[0.12]

cvnix=[0.21]
cvniy=[270]

horx=[-0.0933]
hory=[6]
plt.scatter(hory,horx,color='grey')

tuciiix=[0.4975]

tuciix=[0.32]

segix=[0.57]
segiy=[2.1]
plt.scatter(segiy,segix, color='teal')

segiix=[0.31]
segiiy=[60]
plt.scatter(segiiy,segiix, color='black')

plt.xlabel("Mass (Order of 10^6 Solar Masses)")
plt.ylabel("Mg/Fe")
plt.title("Mg/Fe vs Galactic Mass")
# Out:
# Text(0.5, 1.0, 'Mg/Fe vs Galactic Mass')

# %%
#Mass vs Avg Fe/H
herx=[]
hery=[70]
plt.scatter(herx,hery,color='m')

booiix=[]
booiiy=[26.3]
plt.scatter(booiix,booiiy, color='red')

umax=[]
umay=[50]
plt.scatter(umax,umay, color='orange')

comx=[0.5266]

booix=[]
booiy=[100]
plt.scatter(booix,booiy,color='lime')

retx=[]
rety=[47]
plt.scatter(retx,rety, color='b')

leox=[]
leoy=[15]
plt.scatter(leox,leoy,color='cyan')

cnviix=[0.12]

cvnix=[]
cvniy=[270]
plt.scatter(cvnix,cvniy, color='brown')

horx=[]
hory=[6]
plt.scatter(horx,hory,color='grey')

tuciiix=[0.4975]

tuciix=[0.32]

segix=[]
segiy=[2.1]
plt.scatter(segix,segiy, color='teal')

segiix=[]
segiiy=[60]
plt.scatter(segiix,segiiy, color='black')

plt.scatter(-2.4,-0.34, color='red', marker='*',s=100)
plt.xlabel("Average [Fe/H] of Each UFD")
plt.ylabel("Mass (Order of 10^6 Solar Masses)")
plt.title("Galactic Mass vs Average [Fe/H]")

# %%
#Mass vs Avg Fe/H with Buckets
#Bucket 1: -4.0 to -3.0
import numpy as np
umaxb1=[-3.215]
umayb1=[50]
plt.scatter(umaxb1,umayb1, color='orange')

booixb1=[-3.35]
booiyb1=[100]
plt.scatter(booixb1,booiyb1,color='lime')

retxb1=[-3.23]
retyb1=[47]
plt.scatter(retxb1,retyb1, color='b')

leoxb1=[-3.19]
leoyb1=[15]
plt.scatter(leoxb1,leoyb1,color='cyan')

segixb1=[-3.65]
segiyb1=[2.1]
plt.scatter(segixb1,segiyb1, color='teal')

#Bucket 2: -3.0 to -2.0
herxb2=[-2.3775]
heryb2=[70]
plt.scatter(herxb2,heryb2,color='m')

booiixb2=[-2.82]
booiiyb2=[26.3]
plt.scatter(booiixb2,booiiyb2, color='red')

umaxb2=[-2.39]
umayb2=[50]
plt.scatter(umaxb2,umayb2, color='orange')

booixb2=[-2.3416]
booiyb2=[100]
plt.scatter(booixb2,booiyb2,color='lime')

retxb2=[-2.602]
retyb2=[47]
plt.scatter(retxb2,retyb2, color='b')

leoxb2=[-2.53]
leoyb2=[15]
plt.scatter(leoxb2,leoyb2,color='cyan')

cvnixb2=[-2.35]
cvniyb2=[270]


horxb2=[-2.62]
horyb2=[6]
plt.scatter(horxb2,horyb2,color='grey')

segixb2=[-2.36]
segiyb2=[2.1]
plt.scatter(segixb2,segiyb2, color='teal')

segiixb2=[-2.9]
segiiyb2=[60]
plt.scatter(segiixb2,segiiyb2, color='black')

#Bucket 3: -2.0 to -1.0
booixb3=[-1.895]
booiyb3=[100]
plt.scatter(booixb3,booiyb3,color='lime')

segixb3=[-1.545]
segiyb3=[2.1]
plt.scatter(segixb3,segiyb3, color='teal')

plt.axvline(x=-3.0, color='black', linestyle='-')
plt.axvline(x=-2.0, color='black', linestyle='-')


plt.xlabel("Average [Fe/H] of Each UFD")
plt.ylabel("Mass (Order of 10^6 Solar Masses)")
plt.title("Galactic Mass vs Average [Fe/H] in Buckets")
txt= "Metallicities were split up by 'buckets' with Bucket 1= -4.0 to -3.0, Bucket 2= -3.0 to -2.0, and Bucket 3= -2.0 to -1.0"
plt.figtext(0.5,-0.05,txt,wrap=True, horizontalalignment='center', fontsize=12)
# Out:
# Text(0.5, -0.05, "Metallicities were split up by 'buckets' with Bucket 1= -4.0 to -3.0, Bucket 2= -3.0 to -2.0, and Bucket 3= -2.0 to -1.0")

# %% [markdown]
# ## Abundances as Subplots

# %%
he=-2.4
nadata = np.genfromtxt("na.giant.csv", delimiter=",", names=["nax", "nay"])
naudata = np.genfromtxt("na.ufd.csv", delimiter=",", names=["naux", "nauy"])
hena=-0.61
mgdata = np.genfromtxt("mg.giant.csv", delimiter=",", names=["mgx", "mgy"])
mgudata = np.genfromtxt("mg.ufd.csv", delimiter=",", names=["mgux", "mguy"])
hemg=-0.25
cadata = np.genfromtxt("ca.giant.csv", delimiter=",", names=["cax", "cay"])
caudata = np.genfromtxt("ca.ufd.csv", delimiter=",", names=["caux", "cauy"])
heca=0.22
codata = np.genfromtxt("co.giant.csv", delimiter=",", names=["cox", "coy"])
coudata = np.genfromtxt("co.ufd.csv", delimiter=",", names=["coux", "couy"])
heco=-0.14
nidata = np.genfromtxt("ni.giant.csv", delimiter=",", names=["nix", "niy"])
niudata = np.genfromtxt("ni.ufd.csv", delimiter=",", names=["niux", "niuy"])
heni=-0.51
zndata = np.genfromtxt("zn.giant.csv", delimiter=",", names=["znx", "zny"])
znudata = np.genfromtxt("zn.ufd.csv", delimiter=",", names=["znux", "znuy"])
hezn=-0.79
cdata = np.genfromtxt("c.giant.csv", delimiter=",", names=["cx", "cy"])
cudata = np.genfromtxt("c.ufd.csv", delimiter=",", names=["cux", "cuy"])
hec=-0.35
aldata = np.genfromtxt("al.giant.csv", delimiter=",", names=["alx", "aly"])
aludata = np.genfromtxt("al.ufd.csv", delimiter=",", names=["alux", "aluy"])
heal=-1.18
scdata = np.genfromtxt("sc.giant.csv", delimiter=",", names=["scx", "scy"])
scudata = np.genfromtxt("sc.ufd.csv", delimiter=",", names=["scux", "scuy"])
hesc=-0.72
mndata = np.genfromtxt("mn.giant.csv", delimiter=",", names=["mnx", "mny"])
mnudata = np.genfromtxt("mn.ufd.csv", delimiter=",", names=["mnux", "mnuy"])
hemn=-0.65
crdata = np.genfromtxt("cr.giant.csv", delimiter=",", names=["crx", "cry"])
crudata = np.genfromtxt("cr.ufd.csv", delimiter=",", names=["crux", "cruy"])
hecr=-0.29
vdata = np.genfromtxt("v.giant.csv", delimiter=",", names=["vx", "vy"])
vudata = np.genfromtxt("v.ufd.csv", delimiter=",", names=["vux", "vuy"])
hev=0.02
sidata = np.genfromtxt("si.giant.csv", delimiter=",", names=["six", "siy"])
siudata = np.genfromtxt("si.ufd.csv", delimiter=",", names=["siux", "siuy"])
hesi=-0.19
tidata = np.genfromtxt("ti.giant.csv", delimiter=",", names=["tix", "tiy"])
tiudata = np.genfromtxt("ti.ufd.csv", delimiter=",", names=["tiux", "tiuy"])
heti=-0.19

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as ticker
fig, axs = plt.subplots(3, 5, figsize=(15,7.5), dpi=300,
                        gridspec_kw={'hspace': 0.3, 'wspace': 0.3})

(ax1, ax2,ax3,ax4,ax5), (ax6,ax7,ax8,ax9,ax10),(ax11,ax12,ax13,ax14,ax15) = axs
fig.text(0.51, 0.04, '[Fe/H]', ha='center', va='center',fontsize=25)
fig.text(0.05, 0.5, '[X/Fe]', ha='center', va='center', rotation='vertical',fontsize=25)

#axs.tick_params(axis='y', which='minor', pad=15)


ax1.scatter(cdata['cx'], cdata['cy'],color='grey',s=14,alpha=0.2)
ax1.scatter(cudata['cux'], cudata['cuy'],s=14)
ax1.scatter(he,hec,s=14, color='red',marker='s')
#ax1.set_xlim(-5,0)
fig.text(0.139, 0.85, 'C', fontsize=20,ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax2.scatter(nadata['nax'], nadata['nay'],color='grey',s=14,alpha=0.2)
ax2.scatter(naudata['naux'], naudata['nauy'],s=14)
ax2.scatter(he,hena,s=14, color='red',marker='s')
#ax2.set_xlim(-5,0)
fig.text(0.305, 0.85, 'Na',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax3.scatter(mgdata['mgx'], mgdata['mgy'],color='grey',s=14,alpha=0.2)
ax3.scatter(mgudata['mgux'], mgudata['mguy'],s=14)
ax3.scatter(he,hemg,s=14, color='red',marker='s')
#ax3.set_xlim(-5,0)
fig.text(0.47, 0.85, 'Mg',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax4.scatter(aldata['alx'], aldata['aly'],color='grey',s=14,alpha=0.2)
ax4.scatter(aludata['alux'], aludata['aluy'],s=14)
ax4.scatter(he,heal,s=14, color='red',marker='s')
#ax4.set_xlim(-5,0)
fig.text(0.63, 0.85, 'Al',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax5.scatter(sidata['six'], sidata['siy'],color='grey',s=14,alpha=0.2)
ax5.scatter(siudata['siux'], siudata['siuy'],s=14)
ax5.scatter(he,hesi,s=14, color='red',marker='s')
#ax5.set_xlim(-5,0)
fig.text(0.79, 0.85, 'Si',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax6.scatter(cadata['cax'], cadata['cay'],color='grey',s=14,alpha=0.2)
ax6.scatter(caudata['caux'], caudata['cauy'],s=14)
ax6.scatter(he,heca,s=14, color='red',marker='s')
#ax6.set_ylim(-0.5,1.75)
fig.text(0.145, 0.575, 'Ca',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax7.scatter(scdata['scx'], scdata['scy'],color='grey',s=14,alpha=0.2)
ax7.scatter(scudata['scux'], scudata['scuy'],s=14)
ax7.scatter(he,hesc,s=14, color='red',marker='s')
ax7.set_xlim(-5.5,0)
fig.text(0.305, 0.575, 'Sc',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax8.scatter(tidata['tix'], tidata['tiy'],color='grey',s=14,alpha=0.2)
ax8.scatter(tiudata['tiux'], tiudata['tiuy'],s=14)
ax8.scatter(he,heti,s=14, color='red',marker='s')
fig.text(0.465, 0.575, 'Ti', fontsize=20,ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax9.scatter(vdata['vx'], vdata['vy'],color='grey',s=14,alpha=0.2)
ax9.scatter(vudata['vux'], vudata['vuy'],s=14)
ax9.scatter(he,hev,s=14, color='red',marker='s')
ax9.set_ylim(-1,2)
ax9.set_xlim(-5,0)
fig.text(0.625, 0.575, 'V',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax10.scatter(crdata['crx'], crdata['cry'],color='grey',s=14,alpha=0.2)
ax10.scatter(crudata['crux'], crudata['cruy'],s=14)
ax10.scatter(he,hecr,s=14, color='red',marker='s')
fig.text(0.793, 0.575, 'Cr',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax11.scatter(mndata['mnx'], mndata['mny'],color='grey',s=14,alpha=0.2)
ax11.scatter(mnudata['mnux'], mnudata['mnuy'],s=14)
ax11.scatter(he,hemn,s=14, color='red',marker='s')
ax11.set_xlim(-5,-1.5)
fig.text(0.145, 0.303, 'Mn',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax12.scatter(codata['cox'], codata['coy'],color='grey',s=14,alpha=0.2)
ax12.scatter(coudata['coux'], coudata['couy'],s=14)
ax12.scatter(he,heco,s=14, color='red',marker='s')
fig.text(0.305, 0.303, 'Co',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax13.scatter(nidata['nix'], nidata['niy'],color='grey',s=14,alpha=0.2)
ax13.scatter(niudata['niux'], niudata['niuy'],s=14)
ax13.scatter(he,heni,s=14, color='red',marker='s')
fig.text(0.465, 0.303, 'Ni',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax14.scatter(zndata['znx'], zndata['zny'],color='grey',s=14,alpha=0.2)
ax14.scatter(znudata['znux'], znudata['znuy'],s=14)
ax14.scatter(he,hezn,s=14, color='red',marker='s')
ax14.set_xlim(-5,-1.5)
fig.text(0.63, 0.303, 'Zn',fontsize=20, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax15.tick_params(axis='x', colors='white')
ax15.tick_params(axis='y', colors='white')
ax15.spines['bottom'].set_color('white')
ax15.spines['top'].set_color('white') 
ax15.spines['right'].set_color('white')
ax15.spines['left'].set_color('white')





legend_elements = [Line2D([0], [0], marker='.', color='w', label='MW Halo Stars',
                         markerfacecolor='grey',markersize=15, alpha=0.5),
                  Line2D([0], [0], marker='.', color='w', label='UFD Stars',
                          markerfacecolor='#1f77b4', markersize=15),
                  Line2D([0], [0], marker='s', color='w', label='J0010−1735',
                          markerfacecolor='red', markersize=8)]
plt.legend(handles=legend_elements,fontsize=15, bbox_to_anchor=(-0.15, 0.2), loc='lower left')
#plt.tick_params(axis='both', which='major',pad=15)
#fig.savefig('test3png.png', dpi=300)
#plt.figure(dpi=150)
plt.savefig('abundcomp.png', dpi=300)
#for ax in axs.flat:
#    ax.label_outer()
#or ax in [ax1, ax2]:
    #ax.xaxis.set_minor_locator(AutoMinorLocator(4))

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axs = plt.subplots(2, 1, sharex='col', #sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0.5})

(ax1, ax2) = axs
fig.text(0.51, 0.04, '[Fe/H]', ha='center', va='center')
fig.text(0.03, 0.5, '[X/Fe]', ha='center', va='center', rotation='vertical')

ax1.scatter(mgdata['mgx'], mgdata['mgy'],color='grey',s=14,alpha=0.2)
ax1.scatter(mgudata['mgux'], mgudata['mguy'],s=14)
ax1.scatter(he,hemg,s=14, color='red',marker='s')
#ax3.set_xlim(-5,0)
fig.text(0.16, 0.84, 'Mg',fontsize=14, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax2.scatter(zndata['znx'], zndata['zny'],color='grey',s=14,alpha=0.2)
ax2.scatter(znudata['znux'], znudata['znuy'],s=14)
ax2.scatter(he,hezn,s=14, color='red',marker='s')
ax2.set_ylim(-1,2.5)
ax2.set_xlim(-5,0)
fig.text(0.157, 0.462, 'Zn',fontsize=14, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

legend_elements = [Line2D([0], [0], marker='.', color='w', label='MW Halo Stars',
                         markerfacecolor='grey',markersize=15, alpha=0.5),
                  Line2D([0], [0], marker='.', color='w', label='UFD Stars',
                          markerfacecolor='#1f77b4', markersize=15),
                  Line2D([0], [0], marker='s', color='w', label='J0010−1735',
                          markerfacecolor='red', markersize=8)]
plt.legend(handles=legend_elements, bbox_to_anchor=(0.655, 2.04), loc='upper left')
plt.savefig('mgznabund.png', dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, axs = plt.subplots(2, 1, sharex='col', #sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0.5})

(ax1, ax2) = axs
fig.text(0.51, 0.04, '[Fe/H]', ha='center', va='center')
fig.text(0.03, 0.5, '[X/Fe]', ha='center', va='center', rotation='vertical')

ax1.scatter(cdata['cx'], cdata['cy'],color='grey',s=14,alpha=0.2)
ax1.scatter(cudata['cux'], cudata['cuy'],s=14)
ax1.scatter(he,hemg,s=14, color='red',marker='s')
#ax3.set_xlim(-5,0)
fig.text(0.147, 0.84, 'C',fontsize=14, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

ax2.scatter(nadata['nax'], nadata['nay'],color='grey',s=14,alpha=0.2)
ax2.scatter(naudata['naux'], naudata['nauy'],s=14)
ax2.scatter(he,hezn,s=14, color='red',marker='s')
ax2.set_ylim(-1,2.5)
ax2.set_xlim(-5,0)
fig.text(0.157, 0.462, 'Na',fontsize=14, ha='center', va='center',bbox=dict(facecolor='white', alpha=1))

legend_elements = [Line2D([0], [0], marker='.', color='w', label='MW Halo Stars',
                         markerfacecolor='grey',markersize=15, alpha=0.5),
                  Line2D([0], [0], marker='.', color='w', label='UFD Stars',
                          markerfacecolor='#1f77b4', markersize=15),
                  Line2D([0], [0], marker='s', color='w', label='J0010−1735',
                          markerfacecolor='red', markersize=8)]
plt.legend(handles=legend_elements, bbox_to_anchor=(0.655, 2.04), loc='upper left')
